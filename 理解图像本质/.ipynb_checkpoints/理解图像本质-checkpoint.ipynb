# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open("./img/cat.jpg")

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=600x401>

# %%
type(img)
# Out:
# PIL.WebPImagePlugin.WebPImageFile

# %%
img_arr = np.asarray(img)

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (401, 600, 3)

# %%
plt.imshow(img_arr)

# %%
img_arr_copy = img_arr.copy()

# %%
plt.imshow(img_arr_copy)

# %%
plt.imshow(img_arr_copy[:, :, 0])

# %%
plt.imshow(img_arr_copy[:, :, 0], cmap="magma")

# %%
plt.imshow(img_arr_copy[:, :, 0], cmap="gray")

# %%
img_arr_copy[:, :, 0].shape
# Out:
# (401, 600)

# %%
plt.imshow(img_arr_copy[:, :, 1])

# %%
plt.imshow(img_arr_copy[:, :, 2])

# %%
img_arr_copy[:, :, 1] = 0

# %%
plt.imshow(img_arr_copy)

# %%
img_arr_copy[:, :, 2] = 0

# %%
plt.imshow(img_arr_copy)

# %%
img_arr_copy.shape
# Out:
# (401, 600, 3)

# %%
img_arr_copy[:, :, 0].shape
# Out:
# (401, 600)
